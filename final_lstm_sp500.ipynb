# %% [markdown]
# # Simple LSTM - SP500

# %%
# used ChatGPT to debug some functions

'''
Sources
linear regression: https://www.youtube.com/watch?v=OXwZtlcTiuk&t=69s
lstm: https://www.youtube.com/watch?v=CbTU92pbDKw
'''

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import datetime
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse, r2_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Download Data from yFinance

# %%
# Scrape S&P 500 tickers from Wikipedia
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
sp500_table = pd.read_html(url)[0]
sp500_tickers = sp500_table['Symbol'].tolist()

# %%
# Set date range for 20 years
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=10 * 365)

# download dataset
df = yf.download(sp500_tickers, start=start_date, end=end_date, group_by="ticker")

df
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 2 Failed downloads:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2014-12-13 14:58:35.088593 -> 2024-12-10 14:58:35.088593)')
# Ticker                            SW                                   \
# Price                           Open       High        Low      Close
# Date
# 2014-12-15 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2014-12-16 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2014-12-17 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2014-12-18 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2014-12-19 00:00:00+00:00        NaN        NaN        NaN        NaN
# ...                              ...        ...        ...        ...
# 2024-12-03 00:00:00+00:00  55.310001  55.400002  54.599998  55.220001
# 2024-12-04 00:00:00+00:00  55.500000  55.500000  54.330002  54.570000
# 2024-12-05 00:00:00+00:00  54.689999  54.849998  54.080002  54.770000
# 2024-12-06 00:00:00+00:00  54.790001  54.950001  54.439999  54.610001
# 2024-12-09 00:00:00+00:00  55.009998  55.180000  54.110001  54.340000
#
# Ticker                                                HOLX             \
# Price                      Adj Close     Volume       Open       High
# Date
# 2014-12-15 00:00:00+00:00        NaN        NaN  25.980000  26.219999
# 2014-12-16 00:00:00+00:00        NaN        NaN  25.360001  25.950001
# 2014-12-17 00:00:00+00:00        NaN        NaN  25.750000  26.389999
# 2014-12-18 00:00:00+00:00        NaN        NaN  26.910000  26.980000
# 2014-12-19 00:00:00+00:00        NaN        NaN  26.930000  27.100000
# ...                              ...        ...        ...        ...
# 2024-12-03 00:00:00+00:00  55.220001  2630100.0  78.980003  78.980003
# 2024-12-04 00:00:00+00:00  54.570000  2891900.0  77.959999  77.959999
# 2024-12-05 00:00:00+00:00  54.770000  2428900.0  76.709999  76.849998
# 2024-12-06 00:00:00+00:00  54.610001  1633300.0  75.980003  76.419998
# 2024-12-09 00:00:00+00:00  54.340000  2568200.0  75.839996  76.250000
#
# Ticker                                           ...        AMZN              \
# Price                            Low      Close  ...         Low       Close
# Date                                             ...
# 2014-12-15 00:00:00+00:00  25.400000  25.600000  ...   15.107500   15.303500
# 2014-12-16 00:00:00+00:00  25.260000  25.639999  ...   14.750500   14.753000
# 2014-12-17 00:00:00+00:00  25.660000  26.370001  ...   14.651500   14.944000
# 2014-12-18 00:00:00+00:00  26.490000  26.959999  ...   14.662500   14.886500
# 2014-12-19 00:00:00+00:00  26.809999  26.930000  ...   14.776000   14.995000
# ...                              ...        ...  ...         ...         ...
# 2024-12-03 00:00:00+00:00  77.379997  77.470001  ...  209.649994  213.440002
# 2024-12-04 00:00:00+00:00  76.279999  76.870003  ...  215.750000  218.160004
# 2024-12-05 00:00:00+00:00  75.610001  76.000000  ...  217.300003  220.550003
# 2024-12-06 00:00:00+00:00  75.220001  75.339996  ...  220.600006  227.029999
# 2024-12-09 00:00:00+00:00  74.440002  75.790001  ...  225.669998  226.089996
#
# Ticker                                                   SNA              \
# Price                       Adj Close     Volume        Open        High
# Date
# 2014-12-15 00:00:00+00:00   15.303500   76832000  133.529999  134.429993
# 2014-12-16 00:00:00+00:00   14.753000  130026000  132.289993  135.080002
# 2014-12-17 00:00:00+00:00   14.944000   88670000  132.860001  134.419998
# 2014-12-18 00:00:00+00:00   14.886500  154762000  136.369995  136.960007
# 2014-12-19 00:00:00+00:00   14.995000  174182000  137.770004  137.830002
# ...                               ...        ...         ...         ...
# 2024-12-03 00:00:00+00:00  213.440002   32214800  366.690002  368.540009
# 2024-12-04 00:00:00+00:00  218.160004   48745700  364.010010  366.839996
# 2024-12-05 00:00:00+00:00  220.550003   41140200  361.959991  363.559998
# 2024-12-06 00:00:00+00:00  227.029999   44178100  361.959991  363.100006
# 2024-12-09 00:00:00+00:00  226.089996   46819400  358.079987  359.600006
#
# Ticker
# Price                             Low       Close   Adj Close  Volume
# Date
# 2014-12-15 00:00:00+00:00  131.929993  132.570007  105.827675  283000
# 2014-12-16 00:00:00+00:00  132.289993  132.529999  105.795700  300800
# 2014-12-17 00:00:00+00:00  131.380005  134.229996  107.152748  304900
# 2014-12-18 00:00:00+00:00  135.309998  136.949997  109.324104  396100
# 2014-12-19 00:00:00+00:00  136.669998  136.960007  109.332077  488100
# ...                               ...         ...         ...     ...
# 2024-12-03 00:00:00+00:00  362.260010  365.100006  365.100006  271300
# 2024-12-04 00:00:00+00:00  361.660004  362.859985  362.859985  265600
# 2024-12-05 00:00:00+00:00  359.309998  361.359985  361.359985  332000
# 2024-12-06 00:00:00+00:00  355.630005  357.769989  357.769989  433000
# 2024-12-09 00:00:00+00:00  352.880005  354.600006  354.600006  453200
#
# [2513 rows x 3018 columns]

# %% [markdown]
# #### Reformat the Data

# %%
# select only date and close columns for each ticker
df_selected = {}

# iterate through each ticker and select close data
for ticker in sp500_tickers:
    df_selected[ticker] = df[ticker][['Close']]

# %%
# Concatenate 'Close' values for all tickers into a single DataFrame
df_selected_all = pd.concat({ticker: df[ticker][['Close']] for ticker in sp500_tickers}, axis=1)

# Reset the column names to avoid multi-index columns
df_selected_all.columns = [f'{ticker}_Close' for ticker in df_selected_all.columns.get_level_values(0)]

df_selected_all
# Out:
#                             MMM_Close  AOS_Close   ABT_Close  ABBV_Close  \
# Date
# 2014-12-15 00:00:00+00:00  131.145493  26.730000   43.459999   65.620003
# 2014-12-16 00:00:00+00:00  132.984955  26.535000   43.400002   65.250000
# 2014-12-17 00:00:00+00:00  134.280930  27.055000   44.259998   66.570000
# 2014-12-18 00:00:00+00:00  138.210709  27.514999   45.770000   67.919998
# 2014-12-19 00:00:00+00:00  138.361206  27.230000   46.049999   67.709999
# ...                               ...        ...         ...         ...
# 2024-12-03 00:00:00+00:00  131.149994  74.019997  116.290001  181.500000
# 2024-12-04 00:00:00+00:00  130.449997  73.599998  115.970001  176.460007
# 2024-12-05 00:00:00+00:00  133.330002  72.320000  115.589996  176.169998
# 2024-12-06 00:00:00+00:00  133.110001  72.610001  115.599998  176.190002
# 2024-12-09 00:00:00+00:00  131.490005  73.889999  114.900002  176.570007
#
#                             ACN_Close  ADBE_Close   AMD_Close  AES_Close  \
# Date
# 2014-12-15 00:00:00+00:00   81.879997   73.040001    2.470000      13.01
# 2014-12-16 00:00:00+00:00   82.870003   72.320000    2.500000      12.79
# 2014-12-17 00:00:00+00:00   85.300003   74.000000    2.550000      13.13
# 2014-12-18 00:00:00+00:00   89.739998   74.889999    2.550000      13.21
# 2014-12-19 00:00:00+00:00   90.510002   74.449997    2.570000      13.50
# ...                               ...         ...         ...        ...
# 2024-12-03 00:00:00+00:00  352.540009  516.260010  141.979996      13.05
# 2024-12-04 00:00:00+00:00  360.029999  536.489990  143.990005      13.43
# 2024-12-05 00:00:00+00:00  358.130005  538.219971  141.360001      13.29
# 2024-12-06 00:00:00+00:00  362.700012  552.960022  138.589996      13.05
# 2024-12-09 00:00:00+00:00  359.500000  547.929993  130.869995      13.60
#
#                             AFL_Close     A_Close  ...   WY_Close  WMB_Close  \
# Date                                               ...
# 2014-12-15 00:00:00+00:00   28.764999   38.680000  ...  35.590000  42.139999
# 2014-12-16 00:00:00+00:00   28.905001   38.470001  ...  34.740002  41.840000
# 2014-12-17 00:00:00+00:00   29.535000   39.759998  ...  35.009998  43.630001
# 2014-12-18 00:00:00+00:00   30.160000   40.700001  ...  35.299999  44.799999
# 2014-12-19 00:00:00+00:00   30.590000   41.380001  ...  36.189999  46.000000
# ...                               ...         ...  ...        ...        ...
# 2024-12-03 00:00:00+00:00  106.760002  139.279999  ...  31.719999  56.599998
# 2024-12-04 00:00:00+00:00  106.989998  140.199997  ...  31.240000  56.299999
# 2024-12-05 00:00:00+00:00  107.750000  137.869995  ...  30.959999  57.160000
# 2024-12-06 00:00:00+00:00  107.309998  140.580002  ...  31.290001  56.849998
# 2024-12-09 00:00:00+00:00  105.000000  144.000000  ...  31.740000  54.669998
#
#                             WTW_Close  WYNN_Close  XEL_Close   XYL_Close  \
# Date
# 2014-12-15 00:00:00+00:00  115.231789  145.160004  34.250000   36.240002
# 2014-12-16 00:00:00+00:00  114.993378  140.520004  34.220001   36.270000
# 2014-12-17 00:00:00+00:00  118.225166  138.970001  34.750000   36.910000
# 2014-12-18 00:00:00+00:00  118.384109  145.100006  35.349998   38.099998
# 2014-12-19 00:00:00+00:00  119.205299  150.110001  35.400002   38.590000
# ...                               ...         ...        ...         ...
# 2024-12-03 00:00:00+00:00  329.059998   93.760002  71.000000  127.690002
# 2024-12-04 00:00:00+00:00  332.529999   94.790001  70.720001  127.540001
# 2024-12-05 00:00:00+00:00  330.000000   94.400002  70.860001  126.230003
# 2024-12-06 00:00:00+00:00  322.570007   94.370003  69.739998  126.370003
# 2024-12-09 00:00:00+00:00  312.220001   95.940002  69.110001  129.350006
#
#                             YUM_Close  ZBRA_Close   ZBH_Close   ZTS_Close
# Date
# 2014-12-15 00:00:00+00:00   50.776421   74.669998  107.048546   41.740002
# 2014-12-16 00:00:00+00:00   49.618980   75.010002  105.621361   40.849998
# 2014-12-17 00:00:00+00:00   50.754852   76.180000  108.660194   41.130001
# 2014-12-18 00:00:00+00:00   51.574406   77.949997  111.592232   43.150002
# 2014-12-19 00:00:00+00:00   51.164631   78.099998  111.563110   43.509998
# ...                               ...         ...         ...         ...
# 2024-12-03 00:00:00+00:00  137.720001  406.399994  110.739998  176.940002
# 2024-12-04 00:00:00+00:00  138.160004  411.940002  110.620003  175.320007
# 2024-12-05 00:00:00+00:00  138.130005  404.980011  109.160004  174.770004
# 2024-12-06 00:00:00+00:00  137.630005  409.320007  108.029999  176.460007
# 2024-12-09 00:00:00+00:00  139.080002  411.230011  109.470001  178.149994
#
# [2513 rows x 503 columns]

# %%
# Calculate the average of the 'Close' columns across each row
df_selected_all.loc[:, 'avg_close'] = df_selected_all.mean(axis=1)

# Drop the individual 'Close' columns for each ticker
df_final = df_selected_all[['avg_close']]

df_final
# Out:
# /var/folders/cl/x4g3r0nj7qvb_h2ft5kt0zhw0000gn/T/ipykernel_73145/2052341422.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_selected_all.loc[:, 'avg_close'] = df_selected_all.mean(axis=1)
#                             avg_close
# Date
# 2014-12-15 00:00:00+00:00   70.612362
# 2014-12-16 00:00:00+00:00   70.053221
# 2014-12-17 00:00:00+00:00   71.519444
# 2014-12-18 00:00:00+00:00   73.092746
# 2014-12-19 00:00:00+00:00   73.443230
# ...                               ...
# 2024-12-03 00:00:00+00:00  231.248732
# 2024-12-04 00:00:00+00:00  231.289512
# 2024-12-05 00:00:00+00:00  229.800159
# 2024-12-06 00:00:00+00:00  230.184870
# 2024-12-09 00:00:00+00:00  228.959022
#
# [2513 rows x 1 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2513 entries, 2014-12-15 00:00:00+00:00 to 2024-12-09 00:00:00+00:00
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   avg_close  2513 non-null   float64
# dtypes: float64(1)
# memory usage: 39.3 KB

# %%
# remove timezone
df_final.index = pd.to_datetime(df.index).tz_localize(None)

df_final
# Out:
#              avg_close
# Date
# 2014-12-15   70.612362
# 2014-12-16   70.053221
# 2014-12-17   71.519444
# 2014-12-18   73.092746
# 2014-12-19   73.443230
# ...                ...
# 2024-12-03  231.248732
# 2024-12-04  231.289512
# 2024-12-05  229.800159
# 2024-12-06  230.184870
# 2024-12-09  228.959022
#
# [2513 rows x 1 columns]

# %% [markdown]
# #### EDA

# %%
# plot histogram of close values
plt.hist(df_final['avg_close'], bins=30)
plt.title(f'Histogram of SP500 Close Values')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# plot histogram of mean close values by year
df_year = df_final.copy()
df_year.loc[:, 'year'] = df_year.index.year

# group by year and calculate mean
data_grouped = df_year.groupby('year').mean()

plt.bar(data_grouped.index, data_grouped['avg_close'])
plt.title('SP500 Avg Close by Year')
plt.xlabel('Year')
plt.ylabel('Avg Close')
plt.show()

# %%
# plot the close values over time
plt.plot(df_final.index, df_final['avg_close'])
plt.title(f'SP500 Avg Close Values Over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ## Time Period Used: 10 years

# %% [markdown]
# ### Linear Regression

# %%
# set max date as end_date
end_date_1 = df_final.index.max()

# set min date as start_date
start_date_1 = df_final.index[3]  # get the 4th value (necessary for lstm)

start_date_1, end_date_1
# Out:
# (Timestamp('2014-12-18 00:00:00'), Timestamp('2024-12-09 00:00:00'))

# %%
# drop rows not in start and end range
df_lr = df_final[(df_final.index >= start_date_1) & (df_final.index <= end_date_1)]

df_lr
# Out:
#              avg_close
# Date
# 2014-12-18   73.092746
# 2014-12-19   73.443230
# 2014-12-22   73.783538
# 2014-12-23   73.882196
# 2014-12-24   73.955113
# ...                ...
# 2024-12-03  231.248732
# 2024-12-04  231.289512
# 2024-12-05  229.800159
# 2024-12-06  230.184870
# 2024-12-09  228.959022
#
# [2510 rows x 1 columns]

# %%
# create a 1x3 grid of subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 5))  # Adjust the figure size as needed

# plot histogram of close values
axs[0].hist(df_lr['avg_close'], bins=30)
axs[0].set_title('Histogram of Close Values')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Frequency')

# plot histogram of mean close values by year
df_year = df_lr.copy()
df_year.loc[:, 'year'] = df_year.index.year

# group by year and calculate mean
data_grouped = df_year.groupby('year').mean()

axs[1].bar(data_grouped.index, data_grouped['avg_close'])
axs[1].set_title('Mean Close by Year')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Mean Close')

# plot the close values over time
axs[2].plot(df_lr.index, df_lr['avg_close'])
axs[2].set_title('Close Values Over Time')
axs[2].set_xlabel('Date')
axs[2].set_ylabel('Value')

plt.tight_layout()
plt.show()

# %%
# split the data into train and test sets
df_lm = df_final.reset_index()
X = np.array(df_lm.index).reshape(-1,1)
Y = df_lm['avg_close']
X_train_lr, X_test_lr, y_train_lr, y_test_lr = train_test_split(X, Y, test_size=0.3, random_state=123)

# %%
print(X_train_lr.shape)
print(X_test_lr.shape)
print(y_train_lr.shape)
print(y_test_lr.shape)
# Out:
# (1759, 1)
# (754, 1)
# (1759,)
# (754,)

# %%
# create linear model
lm = LinearRegression()
lm.fit(X_train_lr, y_train_lr)
# Out:
# LinearRegression()

# %%
# predict using the trained model
y_pred_lr = lm.predict(X_test_lr)

# %%
# sort index to maintain alignment with predictions
sorted_indices = np.argsort(X_test_lr.flatten())  # get sorted indices
y_test_sorted = y_test_lr.iloc[sorted_indices]    # sort test data
y_pred_sorted = y_pred_lr[sorted_indices]         # sort predictions

# %%
# plot actual vs predicted
plt.figure(figsize=(10, 6))
plt.plot(y_test_sorted.index, y_test_sorted, label='Actual', color='blue')
plt.plot(y_test_sorted.index, y_pred_sorted, label='Predicted', color='red', linestyle='--')

plt.title('y_test vs y_pred')
plt.xlabel('Date Index')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# calculate scores and store them in a dictionary
evaluation_scores = {
    'Metric': ['r2_score', 'MSE'],
    'Train': [
        r2_score(y_train_lr, lm.predict(X_train_lr)),
        mse(y_train_lr, lm.predict(X_train_lr))
    ],
    'Test': [
        r2_score(y_test_lr, lm.predict(X_test_lr)),
        mse(y_test_lr, lm.predict(X_test_lr))
    ]
}

# convert the dictionary to a df and print
eval_scores_df = pd.DataFrame(evaluation_scores)
eval_scores_df.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_087c6">
#   <thead>
#     <tr>
#       <th id="T_087c6_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_087c6_level0_col1" class="col_heading level0 col1" >Train</th>
#       <th id="T_087c6_level0_col2" class="col_heading level0 col2" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_087c6_row0_col0" class="data row0 col0" >r2_score</td>
#       <td id="T_087c6_row0_col1" class="data row0 col1" >0.925407</td>
#       <td id="T_087c6_row0_col2" class="data row0 col2" >0.924761</td>
#     </tr>
#     <tr>
#       <td id="T_087c6_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_087c6_row1_col1" class="data row1 col1" >138.619551</td>
#       <td id="T_087c6_row1_col2" class="data row1 col2" >137.897163</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### LSTM

# %%
# define function to convert string to datetime
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
# define function to create lstm data structure
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['avg_close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
# convert start and end date to strings
end_date_str = end_date_1.strftime('%Y-%m-%d')
start_date_str = start_date_1.strftime('%Y-%m-%d')

# %%
# create lstm data structure
windowed_df = df_to_windowed_df(df_final, 
                                start_date_str, 
                                end_date_str, 
                                n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2014-12-18   70.612362   70.053221   71.519444   73.092746
# 1     2014-12-19   70.053221   71.519444   73.092746   73.443230
# 2     2014-12-22   71.519444   73.092746   73.443230   73.783538
# 3     2014-12-23   73.092746   73.443230   73.783538   73.882196
# 4     2014-12-24   73.443230   73.783538   73.882196   73.955113
# ...          ...         ...         ...         ...         ...
# 2505  2024-12-03  231.535115  232.192305  231.537215  231.248732
# 2506  2024-12-04  232.192305  231.537215  231.248732  231.289512
# 2507  2024-12-05  231.537215  231.248732  231.289512  229.800159
# 2508  2024-12-06  231.248732  231.289512  229.800159  230.184870
# 2509  2024-12-09  231.289512  229.800159  230.184870  228.959022
#
# [2510 rows x 5 columns]

# %% [markdown]
# Target is the close value for the target date. Target-3,2,1 are the three previous close values that came before the target date.

# %%
# select target and feature variables
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  # separate the dates
  dates = df_as_np[:, 0]

  # feature
  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))  # reshape for lstm input

  # target
  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((2510,), (2510, 3, 1), (2510,))

# %%
# split into training, validation, and test datasets
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]        # 80%

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]  # 10%
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]           # 10%

# plot the splits
plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.title(f'SP500 Close Values')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend(['Train', 'Validation', 'Test'])

plt.xticks(rotation=45)
plt.show()

# %%
# build model
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(32),
                    layers.Dense(1)])

# compile model. select loss, optimizer, and learning rate
model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.01),
              metrics=['mean_absolute_error'])

# fit model and set number of epochs
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

# plot loss per epoch
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13459.8877 - mean_absolute_error: 111.0730 - val_loss: 24360.8125 - val_mean_absolute_error: 155.9704
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 10542.5820 - mean_absolute_error: 96.7646 - val_loss: 20091.9102 - val_mean_absolute_error: 141.6258
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - loss: 8101.5303 - mean_absolute_error: 83.4354 - val_loss: 16532.5723 - val_mean_absolute_error: 128.4466
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 6152.9233 - mean_absolute_error: 70.9201 - val_loss: 13727.6973 - val_mean_absolute_error: 117.0199
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 4742.2173 - mean_absolute_error: 60.0219 - val_loss: 11474.7510 - val_mean_absolute_error: 106.9612
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 3594.8184 - mean_absolute_error: 49.6804 - val_loss: 9658.9619 - val_mean_absolute_error: 98.1066
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 2804.6855 - mean_absolute_error: 41.1181 - val_loss: 8194.5312 - val_mean_absolute_error: 90.3354
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 2216.5911 - mean_absolute_error: 35.5441 - val_loss: 7016.1675 - val_mean_absolute_error: 83.5591
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 1829.7792 - mean_absolute_error: 32.2959 - val_loss: 6099.4819 - val_mean_absolute_error: 77.8809
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 1633.7014 - mean_absolute_error: 30.9564 - val_loss: 5342.2505 - val_mean_absolute_error: 72.8574
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 1385.3501 - mean_absolute_error: 28.1324 - val_loss: 4677.4048 - val_mean_absolute_error: 68.1422
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 1088.6614 - mean_absolute_error: 21.3298 - val_loss: 4019.5417 - val_mean_absolute_error: 63.1308
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 887.6235 - mean_absolute_error: 17.7928 - val_loss: 3455.6497 - val_mean_absolute_error: 58.4945
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 796.0122 - mean_absolute_error: 16.6385 - val_loss: 2970.0605 - val_mean_absolute_error: 54.1850
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 634.0533 - mean_absolute_error: 14.1206 - val_loss: 2556.7490 - val_mean_absolute_error: 50.2265
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 565.2927 - mean_absolute_error: 13.2905 - val_loss: 2195.6731 - val_mean_absolute_error: 46.4934
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 450.1746 - mean_absolute_error: 11.6639 - val_loss: 1890.0564 - val_mean_absolute_error: 43.0818
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 361.3193 - mean_absolute_error: 10.3686 - val_loss: 1623.1545 - val_mean_absolute_error: 39.8639
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 305.3295 - mean_absolute_error: 9.0346 - val_loss: 1385.0214 - val_mean_absolute_error: 36.7562
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 264.0320 - mean_absolute_error: 8.5359 - val_loss: 1181.4825 - val_mean_absolute_error: 33.8753
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 224.1540 - mean_absolute_error: 7.8110 - val_loss: 1004.5981 - val_mean_absolute_error: 31.1551
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 197.6414 - mean_absolute_error: 7.2434 - val_loss: 851.6682 - val_mean_absolute_error: 28.5959
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 163.1340 - mean_absolute_error: 6.4197 - val_loss: 722.4098 - val_mean_absolute_error: 26.2393
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 138.7982 - mean_absolute_error: 5.9354 - val_loss: 613.3005 - val_mean_absolute_error: 24.0728
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 114.7820 - mean_absolute_error: 5.6335 - val_loss: 520.4398 - val_mean_absolute_error: 22.0638
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 100.8586 - mean_absolute_error: 5.1291 - val_loss: 439.7643 - val_mean_absolute_error: 20.1517
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 83.8517 - mean_absolute_error: 4.5072 - val_loss: 370.8609 - val_mean_absolute_error: 18.3658
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 71.0047 - mean_absolute_error: 4.2401 - val_loss: 314.2393 - val_mean_absolute_error: 16.7638
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 67.7374 - mean_absolute_error: 4.1866 - val_loss: 281.6962 - val_mean_absolute_error: 15.9004
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 51.1093 - mean_absolute_error: 3.5303 - val_loss: 223.1416 - val_mean_absolute_error: 13.7771
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 47.5334 - mean_absolute_error: 3.6245 - val_loss: 188.0576 - val_mean_absolute_error: 12.4702
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 40.0731 - mean_absolute_error: 3.2669 - val_loss: 163.0332 - val_mean_absolute_error: 11.5232
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 34.4118 - mean_absolute_error: 3.3174 - val_loss: 134.6114 - val_mean_absolute_error: 10.1894
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 35.4403 - mean_absolute_error: 3.3177 - val_loss: 111.9330 - val_mean_absolute_error: 9.0854
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 26.5956 - mean_absolute_error: 2.7233 - val_loss: 96.3247 - val_mean_absolute_error: 8.3285
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 24.4136 - mean_absolute_error: 2.7135 - val_loss: 80.9901 - val_mean_absolute_error: 7.4956
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 19.3103 - mean_absolute_error: 2.3454 - val_loss: 93.0746 - val_mean_absolute_error: 9.0135
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 23.8684 - mean_absolute_error: 3.1155 - val_loss: 58.6810 - val_mean_absolute_error: 6.1369
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - loss: 19.7318 - mean_absolute_error: 2.5177 - val_loss: 49.5039 - val_mean_absolute_error: 5.4969
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - loss: 15.3401 - mean_absolute_error: 1.9352 - val_loss: 46.0830 - val_mean_absolute_error: 5.5211
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - loss: 15.1501 - mean_absolute_error: 2.2133 - val_loss: 41.3060 - val_mean_absolute_error: 5.3200
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 13.3835 - mean_absolute_error: 2.0509 - val_loss: 31.6744 - val_mean_absolute_error: 4.2074
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 11.2292 - mean_absolute_error: 1.8380 - val_loss: 28.0197 - val_mean_absolute_error: 4.0254
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 11.1801 - mean_absolute_error: 2.0509 - val_loss: 25.6557 - val_mean_absolute_error: 3.8894
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - loss: 10.7595 - mean_absolute_error: 1.9241 - val_loss: 29.2269 - val_mean_absolute_error: 4.4412
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 12.5818 - mean_absolute_error: 2.3320 - val_loss: 22.4537 - val_mean_absolute_error: 3.6405
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 10.2046 - mean_absolute_error: 1.8368 - val_loss: 16.9392 - val_mean_absolute_error: 3.0558
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 9.8682 - mean_absolute_error: 1.8028 - val_loss: 15.2378 - val_mean_absolute_error: 2.8901
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 9.2863 - mean_absolute_error: 2.0111 - val_loss: 12.5436 - val_mean_absolute_error: 2.5978
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - loss: 7.8774 - mean_absolute_error: 1.7700 - val_loss: 13.7287 - val_mean_absolute_error: 2.8886

# %%
# tune model
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(32),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

# compile model. select loss, optimizer, and learning rate
model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# fit model and set number of epochs
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

# plot loss per epoch
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14103.3672 - mean_absolute_error: 113.9181 - val_loss: 27210.6348 - val_mean_absolute_error: 164.8527
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 12441.4404 - mean_absolute_error: 106.1275 - val_loss: 19855.1348 - val_mean_absolute_error: 140.7864
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 7427.2510 - mean_absolute_error: 79.0865 - val_loss: 12905.7480 - val_mean_absolute_error: 113.4536
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 3929.1455 - mean_absolute_error: 52.3065 - val_loss: 7729.3931 - val_mean_absolute_error: 87.7232
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - loss: 1890.9062 - mean_absolute_error: 32.8885 - val_loss: 4870.6724 - val_mean_absolute_error: 69.5472
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - loss: 1144.8882 - mean_absolute_error: 25.8403 - val_loss: 3434.9827 - val_mean_absolute_error: 58.3218
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 861.5209 - mean_absolute_error: 21.8081 - val_loss: 2208.8516 - val_mean_absolute_error: 46.6500
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 403.1898 - mean_absolute_error: 11.5509 - val_loss: 1251.5795 - val_mean_absolute_error: 34.9140
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 212.0433 - mean_absolute_error: 7.6024 - val_loss: 687.2327 - val_mean_absolute_error: 25.6174
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 118.5543 - mean_absolute_error: 5.6776 - val_loss: 384.7857 - val_mean_absolute_error: 18.8530
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 68.0819 - mean_absolute_error: 4.0597 - val_loss: 220.2778 - val_mean_absolute_error: 13.9225
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 40.3121 - mean_absolute_error: 3.2547 - val_loss: 129.0199 - val_mean_absolute_error: 10.2250
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 24.1888 - mean_absolute_error: 2.4433 - val_loss: 83.8405 - val_mean_absolute_error: 8.0143
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 19.6899 - mean_absolute_error: 2.3883 - val_loss: 49.9046 - val_mean_absolute_error: 5.8057
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 15.3129 - mean_absolute_error: 2.0216 - val_loss: 33.9933 - val_mean_absolute_error: 4.6293
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 10.5653 - mean_absolute_error: 1.8409 - val_loss: 22.3723 - val_mean_absolute_error: 3.6209
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 8.4789 - mean_absolute_error: 1.6564 - val_loss: 16.6625 - val_mean_absolute_error: 3.1004
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 7.8928 - mean_absolute_error: 1.6456 - val_loss: 13.4115 - val_mean_absolute_error: 2.9335
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7081 - mean_absolute_error: 1.5657 - val_loss: 10.3799 - val_mean_absolute_error: 2.5135
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 4.9814 - mean_absolute_error: 1.3213 - val_loss: 8.9150 - val_mean_absolute_error: 2.2975
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 5.3843 - mean_absolute_error: 1.4293 - val_loss: 7.2958 - val_mean_absolute_error: 2.0971
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 4.6181 - mean_absolute_error: 1.2863 - val_loss: 6.1355 - val_mean_absolute_error: 1.9458
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 4.4763 - mean_absolute_error: 1.3124 - val_loss: 5.3632 - val_mean_absolute_error: 1.8473
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - loss: 4.0830 - mean_absolute_error: 1.2390 - val_loss: 4.9934 - val_mean_absolute_error: 1.7872
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 3.9678 - mean_absolute_error: 1.2266 - val_loss: 4.4236 - val_mean_absolute_error: 1.6953
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 3.8299 - mean_absolute_error: 1.2558 - val_loss: 5.2953 - val_mean_absolute_error: 1.8866
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 3.7670 - mean_absolute_error: 1.3788 - val_loss: 3.8168 - val_mean_absolute_error: 1.5792
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 2.8245 - mean_absolute_error: 1.0809 - val_loss: 5.7335 - val_mean_absolute_error: 2.0182
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 3.2305 - mean_absolute_error: 1.2192 - val_loss: 3.3844 - val_mean_absolute_error: 1.5018
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 3.4938 - mean_absolute_error: 1.2277 - val_loss: 4.2388 - val_mean_absolute_error: 1.7246
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 3.2026 - mean_absolute_error: 1.1947 - val_loss: 3.9431 - val_mean_absolute_error: 1.5934
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 3.0954 - mean_absolute_error: 1.1607 - val_loss: 2.8105 - val_mean_absolute_error: 1.3670
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 2.7944 - mean_absolute_error: 1.0995 - val_loss: 2.8559 - val_mean_absolute_error: 1.3827
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 3.0714 - mean_absolute_error: 1.1615 - val_loss: 2.9998 - val_mean_absolute_error: 1.3907
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 2.7204 - mean_absolute_error: 1.0902 - val_loss: 4.0984 - val_mean_absolute_error: 1.6128
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 3.1828 - mean_absolute_error: 1.1707 - val_loss: 2.5854 - val_mean_absolute_error: 1.3059
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 2.7033 - mean_absolute_error: 1.1359 - val_loss: 3.9665 - val_mean_absolute_error: 1.5852
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - loss: 2.6997 - mean_absolute_error: 1.1005 - val_loss: 5.5881 - val_mean_absolute_error: 1.9107
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 3.0867 - mean_absolute_error: 1.1379 - val_loss: 3.9831 - val_mean_absolute_error: 1.5868
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 2.3252 - mean_absolute_error: 1.0479 - val_loss: 3.2905 - val_mean_absolute_error: 1.5009
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 2.4415 - mean_absolute_error: 1.0264 - val_loss: 2.4489 - val_mean_absolute_error: 1.2655
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 2.5356 - mean_absolute_error: 1.0567 - val_loss: 3.8811 - val_mean_absolute_error: 1.6499
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 2.8909 - mean_absolute_error: 1.1112 - val_loss: 3.7911 - val_mean_absolute_error: 1.6339
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 2.7181 - mean_absolute_error: 1.0861 - val_loss: 3.2969 - val_mean_absolute_error: 1.4490
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 2.4959 - mean_absolute_error: 1.0358 - val_loss: 3.9666 - val_mean_absolute_error: 1.6612
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 2.1924 - mean_absolute_error: 0.9651 - val_loss: 2.3997 - val_mean_absolute_error: 1.2386
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - loss: 3.0444 - mean_absolute_error: 1.2181 - val_loss: 2.6858 - val_mean_absolute_error: 1.3239
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 2.6263 - mean_absolute_error: 1.1390 - val_loss: 3.1868 - val_mean_absolute_error: 1.4232
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 2.3498 - mean_absolute_error: 0.9855 - val_loss: 2.9427 - val_mean_absolute_error: 1.3756
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 2.8552 - mean_absolute_error: 1.1246 - val_loss: 2.2742 - val_mean_absolute_error: 1.2095

# %%
# get predictions
train_predictions = model.predict(X_train).flatten()
val_predictions = model.predict(X_val).flatten()
test_predictions = model.predict(X_test).flatten()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step

# %%
# 1x3 grid of subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)  # Share y-axis for easier comparison

# 1. plot training predictions
axes[0].plot(dates_train, y_train, label='Training Observations')
axes[0].plot(dates_train, train_predictions, label='Training Predictions')
axes[0].set_title('Training Predictions')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Close Value')
axes[0].legend()
axes[0].tick_params(axis='x', rotation=45)

# 2. plot validation predictions
axes[1].plot(dates_val, y_val, label='Validation Observations')
axes[1].plot(dates_val, val_predictions, label='Validation Predictions')
axes[1].set_title('Validation Predictions')
axes[1].set_xlabel('Date')
axes[1].legend()
axes[1].tick_params(axis='x', rotation=45)

# 3. plot test predictions
axes[2].plot(dates_test, y_test, label='Testing Observations')
axes[2].plot(dates_test, test_predictions, label='Testing Predictions')
axes[2].set_title('{Test Predictions')
axes[2].set_xlabel('Date')
axes[2].legend()
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Result

# %%
# create a 1x2 grid of subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# 1. plot actual vs predicted
axes[0].plot(y_test_sorted.index, y_test_sorted, label='Actual', color='blue')
axes[0].plot(y_test_sorted.index, y_pred_sorted, label='Predicted', color='red', linestyle='--')
axes[0].set_title('Linear Regression')
axes[0].set_xlabel('Date Index')
axes[0].set_ylabel('Close Price')
axes[0].legend()

# 2. lstm predictions
axes[1].plot(dates_train, train_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_train, y_train, color='blue', linewidth=0.8)

axes[1].plot(dates_val, val_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_val, y_val, color='blue', linewidth=0.8)

axes[1].plot(dates_test, test_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_test, y_test, color='blue', linewidth=0.8)

# add a vertical dotted line between the training, validation, and test sets
split_train_val = dates_val[0]
split_val_test = dates_test[0]
axes[1].axvline(x=split_train_val, color='black', linestyle=':', linewidth=0.5)
axes[1].axvline(x=split_val_test, color='black', linestyle=':', linewidth=0.5)

axes[1].set_title('LSTM')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Value')
axes[1].legend(['Training Predictions', 
                'Training Observations',
                'Validation Predictions', 
                'Validation Observations',
                'Testing Predictions', 
                'Testing Observations'])

# Rotate x-axis ticks
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# create dictionary to store mse for lr and lstm models
model_scores = {
    'Model': ['Linear Regression', 'LSTM'],
    'Train': [
        mse(y_train_lr, lm.predict(X_train_lr)),
        history.history['loss'][-1]
    ],
    'Test': [
        mse(y_test_lr, lm.predict(X_test_lr)),
        mse(y_test, test_predictions)
    ]
}

# convert the dictionary to a df and print
model_scores_df = pd.DataFrame(model_scores)
model_scores_df.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_71a3d">
#   <thead>
#     <tr>
#       <th id="T_71a3d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_71a3d_level0_col1" class="col_heading level0 col1" >Train</th>
#       <th id="T_71a3d_level0_col2" class="col_heading level0 col2" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_71a3d_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_71a3d_row0_col1" class="data row0 col1" >138.619551</td>
#       <td id="T_71a3d_row0_col2" class="data row0 col2" >137.897163</td>
#     </tr>
#     <tr>
#       <td id="T_71a3d_row1_col0" class="data row1 col0" >LSTM</td>
#       <td id="T_71a3d_row1_col1" class="data row1 col1" >2.596015</td>
#       <td id="T_71a3d_row1_col2" class="data row1 col2" >520.579895</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Time Period Used: 2 Years

# %% [markdown]
# ### Linear Regression

# %%
# set max date as end_date
end_date_2 = df_final.index.max()

# calculate start date
tentative_start_date_2 = end_date_2 - pd.DateOffset(years=2)  # select last 2 years

# find the closest valid start date
start_date_2 = df_final.index[df_final.index >= tentative_start_date_2].min()

start_date_2, end_date_2
# Out:
# (Timestamp('2022-12-09 00:00:00'), Timestamp('2024-12-09 00:00:00'))

# %%
# drop rows not in start and end range
df_lr = df_final[(df_final.index >= start_date_2) & (df_final.index <= end_date_2)]

df_lr
# Out:
#              avg_close
# Date
# 2022-12-09  162.823652
# 2022-12-12  164.987732
# 2022-12-13  166.049910
# 2022-12-14  164.900950
# 2022-12-15  161.389481
# ...                ...
# 2024-12-03  231.248732
# 2024-12-04  231.289512
# 2024-12-05  229.800159
# 2024-12-06  230.184870
# 2024-12-09  228.959022
#
# [502 rows x 1 columns]

# %%
# create a 1x3 grid of subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 5))  # Adjust the figure size as needed

# plot histogram of close values
axs[0].hist(df_lr['avg_close'], bins=30)
axs[0].set_title('Histogram of Close Values')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Frequency')

# plot histogram of mean close values by year
df_year = df_lr.copy()
df_year.loc[:, 'year'] = df_year.index.year

# group by year and calculate mean
data_grouped = df_year.groupby('year').mean()

axs[1].bar(data_grouped.index, data_grouped['avg_close'])
axs[1].set_title('Mean Close by Year')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Mean Close')

# plot the close values over time
axs[2].plot(df_lr.index, df_lr['avg_close'])
axs[2].set_title('Close Values Over Time')
axs[2].set_xlabel('Date')
axs[2].set_ylabel('Value')

plt.tight_layout()
plt.show()

# %%
# split the data into train and test sets
df_lm = df_final.reset_index()
X = np.array(df_lm.index).reshape(-1,1)
Y = df_lm['avg_close']
X_train_lr, X_test_lr, y_train_lr, y_test_lr = train_test_split(X, Y, test_size=0.3, random_state=123)

# %%
print(X_train_lr.shape)
print(X_test_lr.shape)
print(y_train_lr.shape)
print(y_test_lr.shape)
# Out:
# (1759, 1)
# (754, 1)
# (1759,)
# (754,)

# %%
# create linear model
lm = LinearRegression()
lm.fit(X_train_lr, y_train_lr)
# Out:
# LinearRegression()

# %%
# predict using the trained model
y_pred_lr = lm.predict(X_test_lr)

# %%
# sort index to maintain alignment with predictions
sorted_indices = np.argsort(X_test_lr.flatten())  # get sorted indices
y_test_sorted = y_test_lr.iloc[sorted_indices]    # sort test data
y_pred_sorted = y_pred_lr[sorted_indices]         # sort predictions

# %%
# plot actual vs predicted
plt.figure(figsize=(10, 6))
plt.plot(y_test_sorted.index, y_test_sorted, label='Actual', color='blue')
plt.plot(y_test_sorted.index, y_pred_sorted, label='Predicted', color='red', linestyle='--')

plt.title('y_test vs y_pred')
plt.xlabel('Date Index')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# calculate scores and store them in a dictionary
evaluation_scores = {
    'Metric': ['r2_score', 'MSE'],
    'Train': [
        r2_score(y_train_lr, lm.predict(X_train_lr)),
        mse(y_train_lr, lm.predict(X_train_lr))
    ],
    'Test': [
        r2_score(y_test_lr, lm.predict(X_test_lr)),
        mse(y_test_lr, lm.predict(X_test_lr))
    ]
}

# convert the dictionary to a df and print
eval_scores_df = pd.DataFrame(evaluation_scores)
eval_scores_df.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6d6ac">
#   <thead>
#     <tr>
#       <th id="T_6d6ac_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_6d6ac_level0_col1" class="col_heading level0 col1" >Train</th>
#       <th id="T_6d6ac_level0_col2" class="col_heading level0 col2" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6d6ac_row0_col0" class="data row0 col0" >r2_score</td>
#       <td id="T_6d6ac_row0_col1" class="data row0 col1" >0.925407</td>
#       <td id="T_6d6ac_row0_col2" class="data row0 col2" >0.924761</td>
#     </tr>
#     <tr>
#       <td id="T_6d6ac_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_6d6ac_row1_col1" class="data row1 col1" >138.619551</td>
#       <td id="T_6d6ac_row1_col2" class="data row1 col2" >137.897163</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### LSTM

# %%
# convert start and end date to strings
end_date_str = end_date_2.strftime('%Y-%m-%d')
start_date_str = start_date_2.strftime('%Y-%m-%d')

# %%
# create lstm data structure
windowed_df = df_to_windowed_df(df_final, 
                                start_date_str, 
                                end_date_str, 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2022-12-09  163.017782  163.169770  164.315352  162.823652
# 1    2022-12-12  163.169770  164.315352  162.823652  164.987732
# 2    2022-12-13  164.315352  162.823652  164.987732  166.049910
# 3    2022-12-14  162.823652  164.987732  166.049910  164.900950
# 4    2022-12-15  164.987732  166.049910  164.900950  161.389481
# ..          ...         ...         ...         ...         ...
# 497  2024-12-03  231.535115  232.192305  231.537215  231.248732
# 498  2024-12-04  232.192305  231.537215  231.248732  231.289512
# 499  2024-12-05  231.537215  231.248732  231.289512  229.800159
# 500  2024-12-06  231.248732  231.289512  229.800159  230.184870
# 501  2024-12-09  231.289512  229.800159  230.184870  228.959022
#
# [502 rows x 5 columns]

# %%
# select target and feature variables
dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((502,), (502, 3, 1), (502,))

# %%
# split into training, validation, and test datasets
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]        # 80%

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]  # 10%
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]           # 10%

# plot the splits
plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.title(f'{ticker} Close Values')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend(['Train', 'Validation', 'Test'])

plt.xticks(rotation=45)
plt.show()

# %%
# build model
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(32),
                    layers.Dense(1)])

# compile model. select loss, optimizer, and learning rate
model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.01),
              metrics=['mean_absolute_error'])

# fit model and set number of epochs
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

# plot loss per epoch
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32753.5820 - mean_absolute_error: 180.3357 - val_loss: 43834.8984 - val_mean_absolute_error: 209.2966
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31177.8359 - mean_absolute_error: 175.9480 - val_loss: 42755.2969 - val_mean_absolute_error: 206.7014
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30520.6719 - mean_absolute_error: 174.0846 - val_loss: 41793.5391 - val_mean_absolute_error: 204.3617
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29499.2676 - mean_absolute_error: 171.1134 - val_loss: 40799.5312 - val_mean_absolute_error: 201.9151
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29085.6973 - mean_absolute_error: 169.8822 - val_loss: 39856.2383 - val_mean_absolute_error: 199.5656
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28490.8652 - mean_absolute_error: 168.1251 - val_loss: 38944.1641 - val_mean_absolute_error: 197.2672
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27233.7969 - mean_absolute_error: 164.3775 - val_loss: 38059.4102 - val_mean_absolute_error: 195.0118
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26748.0977 - mean_absolute_error: 162.8575 - val_loss: 37198.4844 - val_mean_absolute_error: 192.7918
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25779.2734 - mean_absolute_error: 159.8446 - val_loss: 36358.7461 - val_mean_absolute_error: 190.6015
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25300.9043 - mean_absolute_error: 158.3479 - val_loss: 35196.5273 - val_mean_absolute_error: 187.5279
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23809.1172 - mean_absolute_error: 153.6233 - val_loss: 34183.3711 - val_mean_absolute_error: 184.8068
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23449.4277 - mean_absolute_error: 152.4175 - val_loss: 33203.3867 - val_mean_absolute_error: 182.1361
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22738.7168 - mean_absolute_error: 150.0031 - val_loss: 32271.8457 - val_mean_absolute_error: 179.5606
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21637.5898 - mean_absolute_error: 146.3369 - val_loss: 31195.9258 - val_mean_absolute_error: 176.5392
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20752.6797 - mean_absolute_error: 143.3030 - val_loss: 30221.0742 - val_mean_absolute_error: 173.7563
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19993.4961 - mean_absolute_error: 140.6024 - val_loss: 29250.7793 - val_mean_absolute_error: 170.9413
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19347.4551 - mean_absolute_error: 138.3010 - val_loss: 28117.1875 - val_mean_absolute_error: 167.5928
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18490.0020 - mean_absolute_error: 135.1466 - val_loss: 27148.0781 - val_mean_absolute_error: 164.6762
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17379.2246 - mean_absolute_error: 131.0173 - val_loss: 26231.9844 - val_mean_absolute_error: 161.8708
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16973.9238 - mean_absolute_error: 129.4170 - val_loss: 25358.8301 - val_mean_absolute_error: 159.1509
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16041.1650 - mean_absolute_error: 125.8199 - val_loss: 24527.1133 - val_mean_absolute_error: 156.5161
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15797.9287 - mean_absolute_error: 124.7690 - val_loss: 23727.0078 - val_mean_absolute_error: 153.9389
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14813.2119 - mean_absolute_error: 120.8143 - val_loss: 22960.9023 - val_mean_absolute_error: 151.4301
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14370.9893 - mean_absolute_error: 118.9628 - val_loss: 22197.0156 - val_mean_absolute_error: 148.8865
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13814.5449 - mean_absolute_error: 116.5630 - val_loss: 21404.4668 - val_mean_absolute_error: 146.2007
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13012.5186 - mean_absolute_error: 113.1096 - val_loss: 20625.0254 - val_mean_absolute_error: 143.5103
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12543.8408 - mean_absolute_error: 110.9818 - val_loss: 19877.3867 - val_mean_absolute_error: 140.8814
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11919.4873 - mean_absolute_error: 108.2176 - val_loss: 19163.4160 - val_mean_absolute_error: 138.3242
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11557.0742 - mean_absolute_error: 106.4220 - val_loss: 18479.8125 - val_mean_absolute_error: 135.8307
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10905.3975 - mean_absolute_error: 103.3669 - val_loss: 17825.7266 - val_mean_absolute_error: 133.4013
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10125.3779 - mean_absolute_error: 99.5374 - val_loss: 17196.2168 - val_mean_absolute_error: 131.0206
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9760.9141 - mean_absolute_error: 97.7081 - val_loss: 16589.0684 - val_mean_absolute_error: 128.6827
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9547.6982 - mean_absolute_error: 96.5678 - val_loss: 16003.7764 - val_mean_absolute_error: 126.3881
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9227.8301 - mean_absolute_error: 94.8659 - val_loss: 15440.5664 - val_mean_absolute_error: 124.1400
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8597.2607 - mean_absolute_error: 91.4642 - val_loss: 14899.1777 - val_mean_absolute_error: 121.9400
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8160.6045 - mean_absolute_error: 89.0428 - val_loss: 14375.9180 - val_mean_absolute_error: 119.7752
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7631.5977 - mean_absolute_error: 86.1697 - val_loss: 13871.1172 - val_mean_absolute_error: 117.6490
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7400.5161 - mean_absolute_error: 84.7643 - val_loss: 13382.2471 - val_mean_absolute_error: 115.5527
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7107.2700 - mean_absolute_error: 82.9318 - val_loss: 12911.4004 - val_mean_absolute_error: 113.4970
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6669.6143 - mean_absolute_error: 80.3395 - val_loss: 12457.4805 - val_mean_absolute_error: 111.4794
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6414.3267 - mean_absolute_error: 78.6808 - val_loss: 12018.7822 - val_mean_absolute_error: 109.4941
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6254.3496 - mean_absolute_error: 77.6290 - val_loss: 11595.0127 - val_mean_absolute_error: 107.5416
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5827.8501 - mean_absolute_error: 74.8786 - val_loss: 11186.4678 - val_mean_absolute_error: 105.6250
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5473.1958 - mean_absolute_error: 72.4937 - val_loss: 10793.3301 - val_mean_absolute_error: 103.7473
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5304.9883 - mean_absolute_error: 71.2442 - val_loss: 10411.8877 - val_mean_absolute_error: 101.8924
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5010.0093 - mean_absolute_error: 69.1656 - val_loss: 10045.8936 - val_mean_absolute_error: 100.0803
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4774.2656 - mean_absolute_error: 67.4678 - val_loss: 9692.1211 - val_mean_absolute_error: 98.2970
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4503.4277 - mean_absolute_error: 65.4734 - val_loss: 9351.7021 - val_mean_absolute_error: 96.5499
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4277.4429 - mean_absolute_error: 63.6574 - val_loss: 9022.3047 - val_mean_absolute_error: 94.8287
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4038.0293 - mean_absolute_error: 61.8129 - val_loss: 8705.6709 - val_mean_absolute_error: 93.1442

# %%
# tune model
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

# compile model. select loss, optimizer, and learning rate
model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# fit model and set number of epochs
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

# plot loss per epoch
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 32959.6914 - mean_absolute_error: 180.9299 - val_loss: 45019.5117 - val_mean_absolute_error: 212.1077
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32317.1777 - mean_absolute_error: 179.1727 - val_loss: 44540.0039 - val_mean_absolute_error: 210.9743
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32053.7910 - mean_absolute_error: 178.4495 - val_loss: 43713.9844 - val_mean_absolute_error: 209.0074
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31318.3496 - mean_absolute_error: 176.3153 - val_loss: 41695.9883 - val_mean_absolute_error: 204.1230
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29173.8457 - mean_absolute_error: 170.1268 - val_loss: 38856.5859 - val_mean_absolute_error: 197.0445
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26170.9707 - mean_absolute_error: 161.0970 - val_loss: 33044.0508 - val_mean_absolute_error: 181.6957
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20784.8457 - mean_absolute_error: 143.1879 - val_loss: 23542.3457 - val_mean_absolute_error: 153.3365
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12710.1016 - mean_absolute_error: 111.4395 - val_loss: 12516.4629 - val_mean_absolute_error: 111.7361
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4734.9175 - mean_absolute_error: 66.3000 - val_loss: 3881.1357 - val_mean_absolute_error: 62.0473
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 662.2007 - mean_absolute_error: 21.3875 - val_loss: 476.6530 - val_mean_absolute_error: 21.1238
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 349.5494 - mean_absolute_error: 16.6880 - val_loss: 742.8797 - val_mean_absolute_error: 26.7029
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 237.4731 - mean_absolute_error: 14.0411 - val_loss: 1195.5128 - val_mean_absolute_error: 34.1424
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 226.4957 - mean_absolute_error: 12.9644 - val_loss: 1133.4012 - val_mean_absolute_error: 33.2204
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 222.4902 - mean_absolute_error: 13.1427 - val_loss: 1024.5555 - val_mean_absolute_error: 31.5406
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 234.6840 - mean_absolute_error: 13.8381 - val_loss: 1064.3463 - val_mean_absolute_error: 32.1679
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 221.2922 - mean_absolute_error: 13.1988 - val_loss: 1015.7279 - val_mean_absolute_error: 31.4023
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 214.3513 - mean_absolute_error: 13.0130 - val_loss: 998.3391 - val_mean_absolute_error: 31.1239
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 233.0619 - mean_absolute_error: 13.9787 - val_loss: 985.5613 - val_mean_absolute_error: 30.9165
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 216.6432 - mean_absolute_error: 13.1435 - val_loss: 1134.0157 - val_mean_absolute_error: 33.2604
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 192.8973 - mean_absolute_error: 11.8705 - val_loss: 929.9572 - val_mean_absolute_error: 30.0539
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 181.6463 - mean_absolute_error: 11.7722 - val_loss: 974.4302 - val_mean_absolute_error: 30.8461
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 153.6505 - mean_absolute_error: 10.6030 - val_loss: 790.3139 - val_mean_absolute_error: 27.6871
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 135.3406 - mean_absolute_error: 10.1021 - val_loss: 682.8652 - val_mean_absolute_error: 25.7074
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 124.0678 - mean_absolute_error: 9.7197 - val_loss: 496.3025 - val_mean_absolute_error: 21.7765
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 85.8615 - mean_absolute_error: 8.0772 - val_loss: 441.0901 - val_mean_absolute_error: 20.5201
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 73.9356 - mean_absolute_error: 7.4804 - val_loss: 481.2133 - val_mean_absolute_error: 21.5888
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 57.6370 - mean_absolute_error: 6.2232 - val_loss: 259.2511 - val_mean_absolute_error: 15.5704
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.0407 - mean_absolute_error: 4.7421 - val_loss: 218.0047 - val_mean_absolute_error: 14.2299
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22.9009 - mean_absolute_error: 4.0392 - val_loss: 169.5857 - val_mean_absolute_error: 12.4491
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14.7617 - mean_absolute_error: 3.1929 - val_loss: 148.7585 - val_mean_absolute_error: 11.6250
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.0702 - mean_absolute_error: 2.8060 - val_loss: 121.9845 - val_mean_absolute_error: 10.4249
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9090 - mean_absolute_error: 2.3688 - val_loss: 86.0901 - val_mean_absolute_error: 8.5520
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4905 - mean_absolute_error: 1.8966 - val_loss: 69.8328 - val_mean_absolute_error: 7.5844
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2524 - mean_absolute_error: 1.8056 - val_loss: 62.3265 - val_mean_absolute_error: 7.1304
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1449 - mean_absolute_error: 1.5986 - val_loss: 63.5329 - val_mean_absolute_error: 7.2806
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4628 - mean_absolute_error: 1.5358 - val_loss: 54.6589 - val_mean_absolute_error: 6.6744
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4446 - mean_absolute_error: 1.5004 - val_loss: 47.3565 - val_mean_absolute_error: 6.1257
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8072 - mean_absolute_error: 1.3305 - val_loss: 38.3928 - val_mean_absolute_error: 5.4183
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5887 - mean_absolute_error: 1.5106 - val_loss: 43.2876 - val_mean_absolute_error: 5.8438
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4554 - mean_absolute_error: 1.4807 - val_loss: 49.2985 - val_mean_absolute_error: 6.3759
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2216 - mean_absolute_error: 1.4835 - val_loss: 41.5061 - val_mean_absolute_error: 5.7291
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6402 - mean_absolute_error: 1.2885 - val_loss: 37.7269 - val_mean_absolute_error: 5.4290
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4861 - mean_absolute_error: 1.2431 - val_loss: 35.8218 - val_mean_absolute_error: 5.2816
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2281 - mean_absolute_error: 1.1675 - val_loss: 36.5986 - val_mean_absolute_error: 5.3584
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8238 - mean_absolute_error: 1.3229 - val_loss: 37.6310 - val_mean_absolute_error: 5.4556
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6238 - mean_absolute_error: 1.2875 - val_loss: 33.6749 - val_mean_absolute_error: 5.1198
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1962 - mean_absolute_error: 1.1905 - val_loss: 28.8617 - val_mean_absolute_error: 4.6573
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5642 - mean_absolute_error: 1.2560 - val_loss: 27.8205 - val_mean_absolute_error: 4.5567
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2544 - mean_absolute_error: 1.4587 - val_loss: 24.7569 - val_mean_absolute_error: 4.2324
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4287 - mean_absolute_error: 1.4548 - val_loss: 25.5150 - val_mean_absolute_error: 4.3166

# %%
# get predictions
train_predictions = model.predict(X_train).flatten()
val_predictions = model.predict(X_val).flatten()
test_predictions = model.predict(X_test).flatten()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step

# %%
# 1x3 grid of subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)  # Share y-axis for easier comparison

# 1. plot training predictions
axes[0].plot(dates_train, y_train, label='Training Observations')
axes[0].plot(dates_train, train_predictions, label='Training Predictions')
axes[0].set_title('Training Predictions')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Close Value')
axes[0].legend()
axes[0].tick_params(axis='x', rotation=45)

# 2. plot validation predictions
axes[1].plot(dates_val, y_val, label='Validation Observations')
axes[1].plot(dates_val, val_predictions, label='Validation Predictions')
axes[1].set_title('Validation Predictions')
axes[1].set_xlabel('Date')
axes[1].legend()
axes[1].tick_params(axis='x', rotation=45)

# 3. plot test predictions
axes[2].plot(dates_test, y_test, label='Testing Observations')
axes[2].plot(dates_test, test_predictions, label='Testing Predictions')
axes[2].set_title('Test Predictions')
axes[2].set_xlabel('Date')
axes[2].legend()
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Result

# %%
# create a 1x2 grid of subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# 1. plot actual vs predicted
axes[0].plot(y_test_sorted.index, y_test_sorted, label='Actual', color='blue')
axes[0].plot(y_test_sorted.index, y_pred_sorted, label='Predicted', color='red', linestyle='--')
axes[0].set_title('Linear Regression')
axes[0].set_xlabel('Date Index')
axes[0].set_ylabel('Close Price')
axes[0].legend()

# 2. lstm predictions
axes[1].plot(dates_train, train_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_train, y_train, color='blue', linewidth=0.8)

axes[1].plot(dates_val, val_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_val, y_val, color='blue', linewidth=0.8)

axes[1].plot(dates_test, test_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_test, y_test, color='blue', linewidth=0.8)

# add a vertical dotted line between the training, validation, and test sets
split_train_val = dates_val[0]
split_val_test = dates_test[0]
axes[1].axvline(x=split_train_val, color='black', linestyle=':', linewidth=0.5)
axes[1].axvline(x=split_val_test, color='black', linestyle=':', linewidth=0.5)

axes[1].set_title('LSTM')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Value')
axes[1].legend(['Training Predictions',
                'Training Observations',
                'Validation Predictions', 
                'Validation Observations',
                'Testing Predictions', 
                'Testing Observations'])

# Rotate x-axis ticks
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# create dictionary to store mse for lr and lstm models
model_scores = {
    'Model': ['Linear Regression', 'LSTM'],
    'Train': [
        mse(y_train_lr, lm.predict(X_train_lr)),
        history.history['loss'][-1]
    ],
    'Test': [
        mse(y_test_lr, lm.predict(X_test_lr)),
        mse(y_test, test_predictions)
    ]
}

# convert the dictionary to a df and print
model_scores_df = pd.DataFrame(model_scores)
model_scores_df.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_96ef2">
#   <thead>
#     <tr>
#       <th id="T_96ef2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_96ef2_level0_col1" class="col_heading level0 col1" >Train</th>
#       <th id="T_96ef2_level0_col2" class="col_heading level0 col2" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_96ef2_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_96ef2_row0_col1" class="data row0 col1" >138.619551</td>
#       <td id="T_96ef2_row0_col2" class="data row0 col2" >137.897163</td>
#     </tr>
#     <tr>
#       <td id="T_96ef2_row1_col0" class="data row1 col0" >LSTM</td>
#       <td id="T_96ef2_row1_col1" class="data row1 col1" >3.286796</td>
#       <td id="T_96ef2_row1_col2" class="data row1 col2" >143.644852</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Time Period Used: 5 Years

# %% [markdown]
# ### Linear Regression

# %%
# set max date as end_date
end_date_3 = df_final.index.max()

# calculate start date
tentative_start_date_3 = end_date_3 - pd.DateOffset(years=5)  # select last 5 years

# find the closest valid start date
start_date_3 = df_final.index[df_final.index >= tentative_start_date_3].min()

start_date_3, end_date_3
# Out:
# (Timestamp('2019-12-09 00:00:00'), Timestamp('2024-12-09 00:00:00'))

# %%
# drop rows not in start and end range
df_lr = df_final[(df_final.index >= start_date_3) & (df_final.index <= end_date_3)]

df_lr
# Out:
#              avg_close
# Date
# 2019-12-09  124.155349
# 2019-12-10  124.135006
# 2019-12-11  124.554792
# 2019-12-12  125.001806
# 2019-12-13  125.174657
# ...                ...
# 2024-12-03  231.248732
# 2024-12-04  231.289512
# 2024-12-05  229.800159
# 2024-12-06  230.184870
# 2024-12-09  228.959022
#
# [1259 rows x 1 columns]

# %%
# create a 1x3 grid of subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 5))  # Adjust the figure size as needed

# plot histogram of close values
axs[0].hist(df_lr['avg_close'], bins=30)
axs[0].set_title('Histogram of Close Values')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Frequency')

# plot histogram of mean close values by year
df_year = df_lr.copy()
df_year.loc[:, 'year'] = df_year.index.year

# group by year and calculate mean
data_grouped = df_year.groupby('year').mean()

axs[1].bar(data_grouped.index, data_grouped['avg_close'])
axs[1].set_title('Mean Close by Year')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Mean Close')

# plot the close values over time
axs[2].plot(df_lr.index, df_lr['avg_close'])
axs[2].set_title('Close Values Over Time')
axs[2].set_xlabel('Date')
axs[2].set_ylabel('Value')

plt.tight_layout()
plt.show()

# %%
# split the data into train and test sets
df_lm = df_final.reset_index()
X = np.array(df_lm.index).reshape(-1,1)
Y = df_lm['avg_close']
X_train_lr, X_test_lr, y_train_lr, y_test_lr = train_test_split(X, Y, test_size=0.3, random_state=123)

# %%
print(X_train_lr.shape)
print(X_test_lr.shape)
print(y_train_lr.shape)
print(y_test_lr.shape)
# Out:
# (1759, 1)
# (754, 1)
# (1759,)
# (754,)

# %%
# create linear model
lm = LinearRegression()
lm.fit(X_train_lr, y_train_lr)
# Out:
# LinearRegression()

# %%
# predict using the trained model
y_pred_lr = lm.predict(X_test_lr)

# %%
# sort index to maintain alignment with predictions
sorted_indices = np.argsort(X_test_lr.flatten())  # get sorted indices
y_test_sorted = y_test_lr.iloc[sorted_indices]    # sort test data
y_pred_sorted = y_pred_lr[sorted_indices]         # sort predictions

# %%
# plot actual vs predicted
plt.figure(figsize=(10, 6))
plt.plot(y_test_sorted.index, y_test_sorted, label='Actual', color='blue')
plt.plot(y_test_sorted.index, y_pred_sorted, label='Predicted', color='red', linestyle='--')

plt.title('y_test vs y_pred')
plt.xlabel('Date Index')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# calculate scores and store them in a dictionary
evaluation_scores = {
    'Metric': ['r2_score', 'MSE'],
    'Train': [
        r2_score(y_train_lr, lm.predict(X_train_lr)),
        mse(y_train_lr, lm.predict(X_train_lr))
    ],
    'Test': [
        r2_score(y_test_lr, lm.predict(X_test_lr)),
        mse(y_test_lr, lm.predict(X_test_lr))
    ]
}

# convert the dictionary to a df and print
eval_scores_df = pd.DataFrame(evaluation_scores)
eval_scores_df.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_421f1">
#   <thead>
#     <tr>
#       <th id="T_421f1_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_421f1_level0_col1" class="col_heading level0 col1" >Train</th>
#       <th id="T_421f1_level0_col2" class="col_heading level0 col2" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_421f1_row0_col0" class="data row0 col0" >r2_score</td>
#       <td id="T_421f1_row0_col1" class="data row0 col1" >0.925407</td>
#       <td id="T_421f1_row0_col2" class="data row0 col2" >0.924761</td>
#     </tr>
#     <tr>
#       <td id="T_421f1_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_421f1_row1_col1" class="data row1 col1" >138.619551</td>
#       <td id="T_421f1_row1_col2" class="data row1 col2" >137.897163</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### LSTM

# %%
# convert start and end date to strings
end_date_str = end_date_3.strftime('%Y-%m-%d')
start_date_str = start_date_3.strftime('%Y-%m-%d')

# %%
# create lstm data structure
windowed_df = df_to_windowed_df(df_final, 
                                start_date_str, 
                                end_date_str, 
                                n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2019-12-09  123.567253  123.844034  124.615977  124.155349
# 1     2019-12-10  123.844034  124.615977  124.155349  124.135006
# 2     2019-12-11  124.615977  124.155349  124.135006  124.554792
# 3     2019-12-12  124.155349  124.135006  124.554792  125.001806
# 4     2019-12-13  124.135006  124.554792  125.001806  125.174657
# ...          ...         ...         ...         ...         ...
# 1254  2024-12-03  231.535115  232.192305  231.537215  231.248732
# 1255  2024-12-04  232.192305  231.537215  231.248732  231.289512
# 1256  2024-12-05  231.537215  231.248732  231.289512  229.800159
# 1257  2024-12-06  231.248732  231.289512  229.800159  230.184870
# 1258  2024-12-09  231.289512  229.800159  230.184870  228.959022
#
# [1259 rows x 5 columns]

# %%
# select target and feature variables
dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((1259,), (1259, 3, 1), (1259,))

# %%
# split into training, validation, and test datasets
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]        # 80%

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]  # 10%
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]           # 10%

# plot the splits
plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.title(f'{ticker} Close Values')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend(['Train', 'Validation', 'Test'])

plt.xticks(rotation=45)
plt.show()

# %%
# build model
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(32),
                    layers.Dense(1)])

# compile model. select loss, optimizer, and learning rate
model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.01),
              metrics=['mean_absolute_error'])

# fit model and set number of epochs
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

# plot loss per epoch
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23991.1035 - mean_absolute_error: 153.3976 - val_loss: 35715.8203 - val_mean_absolute_error: 188.8940
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21830.0254 - mean_absolute_error: 146.2733 - val_loss: 33361.4922 - val_mean_absolute_error: 182.5558
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 19522.5156 - mean_absolute_error: 137.9374 - val_loss: 30854.2852 - val_mean_absolute_error: 175.5546
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - loss: 17899.8633 - mean_absolute_error: 132.0591 - val_loss: 28092.7285 - val_mean_absolute_error: 167.5048
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 15767.3672 - mean_absolute_error: 123.6829 - val_loss: 25772.4453 - val_mean_absolute_error: 160.4294
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 14163.7090 - mean_absolute_error: 117.0760 - val_loss: 23702.6270 - val_mean_absolute_error: 153.8433
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 12765.8955 - mean_absolute_error: 110.9603 - val_loss: 21816.9902 - val_mean_absolute_error: 147.5877
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 11540.2705 - mean_absolute_error: 105.3556 - val_loss: 20090.6113 - val_mean_absolute_error: 141.6183
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 10249.4160 - mean_absolute_error: 98.7916 - val_loss: 18502.2109 - val_mean_absolute_error: 135.8946
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 9137.6523 - mean_absolute_error: 93.3350 - val_loss: 17041.8320 - val_mean_absolute_error: 130.4107
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 8218.4648 - mean_absolute_error: 88.2090 - val_loss: 15687.9385 - val_mean_absolute_error: 125.1122
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 7323.1562 - mean_absolute_error: 82.9084 - val_loss: 14438.3105 - val_mean_absolute_error: 120.0143
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 6443.7222 - mean_absolute_error: 77.3510 - val_loss: 13291.1016 - val_mean_absolute_error: 115.1357
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 5737.6641 - mean_absolute_error: 72.7300 - val_loss: 12233.2549 - val_mean_absolute_error: 110.4463
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 4912.4170 - mean_absolute_error: 66.5858 - val_loss: 11267.2539 - val_mean_absolute_error: 105.9829
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 4468.4380 - mean_absolute_error: 63.5598 - val_loss: 10369.5342 - val_mean_absolute_error: 101.6596
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 3945.8591 - mean_absolute_error: 59.0501 - val_loss: 9547.6943 - val_mean_absolute_error: 97.5337
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 3564.3757 - mean_absolute_error: 56.0090 - val_loss: 8796.5713 - val_mean_absolute_error: 93.6040
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 3000.6509 - mean_absolute_error: 50.6101 - val_loss: 8110.9644 - val_mean_absolute_error: 89.8671
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - loss: 2724.6594 - mean_absolute_error: 48.3404 - val_loss: 7482.5547 - val_mean_absolute_error: 86.3000
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 2356.7976 - mean_absolute_error: 44.5384 - val_loss: 6914.3262 - val_mean_absolute_error: 82.9425
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 2056.2034 - mean_absolute_error: 41.0264 - val_loss: 6392.8110 - val_mean_absolute_error: 79.7367
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 1863.6700 - mean_absolute_error: 39.0907 - val_loss: 5913.8340 - val_mean_absolute_error: 76.6744
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 1624.7092 - mean_absolute_error: 36.0732 - val_loss: 5485.2881 - val_mean_absolute_error: 73.8269
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 1458.1399 - mean_absolute_error: 34.1857 - val_loss: 5094.1255 - val_mean_absolute_error: 71.1284
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 1313.7634 - mean_absolute_error: 32.0287 - val_loss: 4739.2461 - val_mean_absolute_error: 68.5884
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 1127.5604 - mean_absolute_error: 29.7489 - val_loss: 4419.4731 - val_mean_absolute_error: 66.2163
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 1009.3782 - mean_absolute_error: 28.1640 - val_loss: 4124.1470 - val_mean_absolute_error: 63.9476
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 890.5374 - mean_absolute_error: 25.8217 - val_loss: 3843.0491 - val_mean_absolute_error: 61.7106
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 746.2437 - mean_absolute_error: 23.0155 - val_loss: 3582.3696 - val_mean_absolute_error: 59.5609
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 669.4447 - mean_absolute_error: 21.6510 - val_loss: 3340.5266 - val_mean_absolute_error: 57.4949
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 613.0447 - mean_absolute_error: 20.9743 - val_loss: 3119.6394 - val_mean_absolute_error: 55.5408
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 523.7257 - mean_absolute_error: 18.8573 - val_loss: 2917.3433 - val_mean_absolute_error: 53.6887
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 449.8419 - mean_absolute_error: 17.2648 - val_loss: 2734.7537 - val_mean_absolute_error: 51.9605
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 390.4189 - mean_absolute_error: 15.8605 - val_loss: 2564.0620 - val_mean_absolute_error: 50.2912
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 354.9761 - mean_absolute_error: 15.1097 - val_loss: 2408.3518 - val_mean_absolute_error: 48.7185
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 306.7268 - mean_absolute_error: 13.9040 - val_loss: 2267.0515 - val_mean_absolute_error: 47.2461
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 283.3796 - mean_absolute_error: 13.4298 - val_loss: 2136.7595 - val_mean_absolute_error: 45.8466
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - loss: 246.1990 - mean_absolute_error: 12.3523 - val_loss: 2018.8557 - val_mean_absolute_error: 44.5421
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 219.0456 - mean_absolute_error: 11.3429 - val_loss: 1909.4213 - val_mean_absolute_error: 43.2963
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 191.6985 - mean_absolute_error: 10.6450 - val_loss: 1810.4009 - val_mean_absolute_error: 42.1374
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 175.1985 - mean_absolute_error: 10.0293 - val_loss: 1718.3536 - val_mean_absolute_error: 41.0304
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 152.7666 - mean_absolute_error: 9.3222 - val_loss: 1634.6254 - val_mean_absolute_error: 39.9977
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 133.6460 - mean_absolute_error: 8.8046 - val_loss: 1556.6250 - val_mean_absolute_error: 39.0099
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 116.2517 - mean_absolute_error: 8.0990 - val_loss: 1485.3417 - val_mean_absolute_error: 38.0853
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 102.9397 - mean_absolute_error: 7.5013 - val_loss: 1419.5331 - val_mean_absolute_error: 37.2113
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 86.3595 - mean_absolute_error: 6.8598 - val_loss: 1358.4656 - val_mean_absolute_error: 36.3815
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 90.6515 - mean_absolute_error: 7.1332 - val_loss: 1301.5740 - val_mean_absolute_error: 35.5916
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 77.8465 - mean_absolute_error: 6.4726 - val_loss: 1249.3820 - val_mean_absolute_error: 34.8503
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 73.5330 - mean_absolute_error: 6.3398 - val_loss: 1200.1520 - val_mean_absolute_error: 34.1368

# %%
# tune model
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(32),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

# compile model. select loss, optimizer, and learning rate
model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# fit model and set number of epochs
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

# plot loss per epoch
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 24541.1016 - mean_absolute_error: 155.2204 - val_loss: 37694.5000 - val_mean_absolute_error: 194.0609
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23300.5078 - mean_absolute_error: 151.0574 - val_loss: 32232.5762 - val_mean_absolute_error: 179.4369
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16821.9336 - mean_absolute_error: 127.1163 - val_loss: 11529.7676 - val_mean_absolute_error: 107.2149
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 2559.3364 - mean_absolute_error: 44.1867 - val_loss: 1345.7441 - val_mean_absolute_error: 36.1837
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 469.5494 - mean_absolute_error: 17.4299 - val_loss: 1922.2081 - val_mean_absolute_error: 43.4442
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 413.3567 - mean_absolute_error: 17.1669 - val_loss: 1503.3296 - val_mean_absolute_error: 38.3808
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 225.5626 - mean_absolute_error: 12.8542 - val_loss: 898.1791 - val_mean_absolute_error: 29.6325
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - loss: 68.4246 - mean_absolute_error: 6.8377 - val_loss: 391.3333 - val_mean_absolute_error: 19.3425
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 21.4096 - mean_absolute_error: 3.6708 - val_loss: 323.1127 - val_mean_absolute_error: 17.5840
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 16.0501 - mean_absolute_error: 3.1569 - val_loss: 235.0283 - val_mean_absolute_error: 14.8782
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 11.5928 - mean_absolute_error: 2.5626 - val_loss: 186.4084 - val_mean_absolute_error: 13.1695
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 11.5435 - mean_absolute_error: 2.6741 - val_loss: 152.2394 - val_mean_absolute_error: 11.8177
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 6.9721 - mean_absolute_error: 2.0093 - val_loss: 123.3983 - val_mean_absolute_error: 10.5487
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 8.0166 - mean_absolute_error: 2.1688 - val_loss: 132.6261 - val_mean_absolute_error: 11.0301
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 6.8902 - mean_absolute_error: 1.9845 - val_loss: 121.9647 - val_mean_absolute_error: 10.5753
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 5.9398 - mean_absolute_error: 1.8796 - val_loss: 133.7368 - val_mean_absolute_error: 11.1665
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 6.3846 - mean_absolute_error: 1.9460 - val_loss: 107.0451 - val_mean_absolute_error: 9.8909
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - loss: 6.2638 - mean_absolute_error: 1.9817 - val_loss: 106.9678 - val_mean_absolute_error: 9.9127
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 6.1265 - mean_absolute_error: 1.9319 - val_loss: 90.5689 - val_mean_absolute_error: 9.0405
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 4.4930 - mean_absolute_error: 1.6088 - val_loss: 78.5818 - val_mean_absolute_error: 8.3502
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 5.3118 - mean_absolute_error: 1.7498 - val_loss: 92.0744 - val_mean_absolute_error: 9.1828
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 5.6408 - mean_absolute_error: 1.7725 - val_loss: 66.3362 - val_mean_absolute_error: 7.6137
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 5.1628 - mean_absolute_error: 1.6887 - val_loss: 74.5781 - val_mean_absolute_error: 8.1708
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 5.2126 - mean_absolute_error: 1.6709 - val_loss: 61.6221 - val_mean_absolute_error: 7.3247
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 5.1983 - mean_absolute_error: 1.6961 - val_loss: 67.8975 - val_mean_absolute_error: 7.7721
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - loss: 5.0843 - mean_absolute_error: 1.7013 - val_loss: 53.2970 - val_mean_absolute_error: 6.7291
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 5.5541 - mean_absolute_error: 1.8416 - val_loss: 53.6858 - val_mean_absolute_error: 6.7740
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - loss: 4.2624 - mean_absolute_error: 1.5331 - val_loss: 46.4014 - val_mean_absolute_error: 6.1999
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 5.0389 - mean_absolute_error: 1.6522 - val_loss: 65.1634 - val_mean_absolute_error: 7.6373
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - loss: 4.8060 - mean_absolute_error: 1.6354 - val_loss: 68.8587 - val_mean_absolute_error: 7.8974
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - loss: 5.2659 - mean_absolute_error: 1.7341 - val_loss: 87.7026 - val_mean_absolute_error: 9.0401
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 6.2252 - mean_absolute_error: 1.9696 - val_loss: 51.5469 - val_mean_absolute_error: 6.6649
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 4.6196 - mean_absolute_error: 1.6636 - val_loss: 65.4043 - val_mean_absolute_error: 7.6679
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 4.9379 - mean_absolute_error: 1.6849 - val_loss: 55.8709 - val_mean_absolute_error: 7.0070
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 4.9558 - mean_absolute_error: 1.6720 - val_loss: 42.4116 - val_mean_absolute_error: 5.9394
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 4.6482 - mean_absolute_error: 1.6349 - val_loss: 46.9599 - val_mean_absolute_error: 6.3325
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - loss: 4.6740 - mean_absolute_error: 1.6370 - val_loss: 51.6002 - val_mean_absolute_error: 6.7095
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 4.3034 - mean_absolute_error: 1.5938 - val_loss: 22.1817 - val_mean_absolute_error: 3.9833
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - loss: 7.6419 - mean_absolute_error: 2.2425 - val_loss: 58.8409 - val_mean_absolute_error: 7.2460
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - loss: 4.9135 - mean_absolute_error: 1.6935 - val_loss: 27.4091 - val_mean_absolute_error: 4.5376
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 7.6976 - mean_absolute_error: 2.1773 - val_loss: 63.9150 - val_mean_absolute_error: 7.5915
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 4.6375 - mean_absolute_error: 1.6575 - val_loss: 57.0884 - val_mean_absolute_error: 7.1208
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 5.1920 - mean_absolute_error: 1.6921 - val_loss: 43.5945 - val_mean_absolute_error: 6.0819
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 5.0116 - mean_absolute_error: 1.6392 - val_loss: 53.0231 - val_mean_absolute_error: 6.8514
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 4.9674 - mean_absolute_error: 1.7259 - val_loss: 34.4298 - val_mean_absolute_error: 5.2939
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 6.5989 - mean_absolute_error: 2.0345 - val_loss: 56.6992 - val_mean_absolute_error: 7.1142
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 6.0099 - mean_absolute_error: 1.9297 - val_loss: 54.9270 - val_mean_absolute_error: 6.9914
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 4.3459 - mean_absolute_error: 1.5913 - val_loss: 55.9702 - val_mean_absolute_error: 7.0780
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 5.1918 - mean_absolute_error: 1.6841 - val_loss: 46.8636 - val_mean_absolute_error: 6.3938
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 4.9229 - mean_absolute_error: 1.5937 - val_loss: 41.7661 - val_mean_absolute_error: 5.9796

# %%
# get predictions
train_predictions = model.predict(X_train).flatten()
val_predictions = model.predict(X_val).flatten()
test_predictions = model.predict(X_test).flatten()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step

# %%
# 1x3 grid of subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)  # Share y-axis for easier comparison

# 1. plot training predictions
axes[0].plot(dates_train, y_train, label='Training Observations')
axes[0].plot(dates_train, train_predictions, label='Training Predictions')
axes[0].set_title('Training Predictions')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Close Value')
axes[0].legend()
axes[0].tick_params(axis='x', rotation=45)

# 2. plot validation predictions
axes[1].plot(dates_val, y_val, label='Validation Observations')
axes[1].plot(dates_val, val_predictions, label='Validation Predictions')
axes[1].set_title('Validation Predictions')
axes[1].set_xlabel('Date')
axes[1].legend()
axes[1].tick_params(axis='x', rotation=45)

# 3. plot test predictions
axes[2].plot(dates_test, y_test, label='Testing Observations')
axes[2].plot(dates_test, test_predictions, label='Testing Predictions')
axes[2].set_title('Test Predictions')
axes[2].set_xlabel('Date')
axes[2].legend()
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Result

# %%
# create a 1x2 grid of subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# 1. plot actual vs predicted
axes[0].plot(y_test_sorted.index, y_test_sorted, label='Actual', color='blue')
axes[0].plot(y_test_sorted.index, y_pred_sorted, label='Predicted', color='red', linestyle='--')
axes[0].set_title('Linear Regression')
axes[0].set_xlabel('Date Index')
axes[0].set_ylabel('Close Price')
axes[0].legend()

# limit x-axis to be same length as lstm graph
axes[0].set_xlim(y.shape[0], y_test_sorted.index[-1])

# 2. lstm predictions
axes[1].plot(dates_train, train_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_train, y_train, color='blue', linewidth=0.8)

axes[1].plot(dates_val, val_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_val, y_val, color='blue', linewidth=0.8)

axes[1].plot(dates_test, test_predictions, color='red', linestyle='--', linewidth=0.8)
axes[1].plot(dates_test, y_test, color='blue', linewidth=0.8)

# add a vertical dotted line between the training, validation, and test sets
split_train_val = dates_val[0]
split_val_test = dates_test[0]
axes[1].axvline(x=split_train_val, color='black', linestyle=':', linewidth=0.5)
axes[1].axvline(x=split_val_test, color='black', linestyle=':', linewidth=0.5)

axes[1].set_title('LSTM')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Value')
axes[1].legend(['Training Predictions', 
                'Training Observations',
                'Validation Predictions', 
                'Validation Observations',
                'Testing Predictions', 
                'Testing Observations'])

# Rotate x-axis ticks
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# create dictionary to store mse for lr and lstm models
model_scores = {
    'Model': ['Linear Regression', 'LSTM'],
    'Train': [
        mse(y_train_lr, lm.predict(X_train_lr)),
        history.history['loss'][-1]
    ],
    'Test': [
        mse(y_test_lr, lm.predict(X_test_lr)),
        mse(y_test, test_predictions)
    ]
}

# convert the dictionary to a df and print
model_scores_df = pd.DataFrame(model_scores)
model_scores_df.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7accc">
#   <thead>
#     <tr>
#       <th id="T_7accc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7accc_level0_col1" class="col_heading level0 col1" >Train</th>
#       <th id="T_7accc_level0_col2" class="col_heading level0 col2" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7accc_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_7accc_row0_col1" class="data row0 col1" >138.619551</td>
#       <td id="T_7accc_row0_col2" class="data row0 col2" >137.897163</td>
#     </tr>
#     <tr>
#       <td id="T_7accc_row1_col0" class="data row1 col0" >LSTM</td>
#       <td id="T_7accc_row1_col1" class="data row1 col1" >4.248165</td>
#       <td id="T_7accc_row1_col2" class="data row1 col2" >285.449097</td>
#     </tr>
#   </tbody>
# </table>
